# %% [markdown]
# # RECOMIENDAME UN LIBRO
# (**Base de datos de libros en inglés de goodreads**)
# ___
# ___

# %% [markdown]
# ## 1 Carga de librerias, accesos y bases
# ___

# %%
import nltk
import pandas as pd
import string as strg
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from nltk.stem.porter import PorterStemmer
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics.pairwise import cosine_similarity

nltk.download('wordnet')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Unzipping corpora/wordnet.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
# Acceso
from google.colab import drive
drive.mount('/content/drive')

# %cd '/content/drive/My Drive/Colab Notebooks/1_Datasets'
# %ls -al
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/My Drive/Colab Notebooks/1_Datasets
# total 15527
# -rw------- 1 root root 8934363 Apr 17 19:16 1.1_input_dataset.csv
# -rw------- 1 root root 1926620 Apr 24 00:22 1.2_sample_dataset.csv
# -rw------- 1 root root 1408773 Apr 24 00:24 1.3_clean_dataset.csv
# -rw------- 1 root root 1435591 Apr 24 00:29 1.4_cluster_dataset.csv
# -rw------- 1 root root 2193608 Apr 24 02:03 1.5_encoding_dataset.csv

# %%
df = pd.read_csv('1.4_cluster_dataset.csv', index_col=0)

# %%
df.head(3)
# Out:
#          ISBN                                               Name  \
# 0  0439554896  Harry Potter and the Chamber of Secrets (Harry...
# 1  0976540606  Unauthorized Harry Potter Book Seven News: "Ha...
# 2  0767910435  Bryson's Dictionary of Troublesome Words: A Wr...
#
#                   Authors       Publisher  Rating  pagesNumber  \
# 0            J.K. Rowling      Scholastic    4.42          352
# 1  W. Frederick Zimmerman    Nimble Books    3.79          152
# 2             Bill Bryson  Broadway Books    3.88          256
#
#    CountsOfReview  PublishYear  Cluster
# 0             244         2003        2
# 1               1         2005        0
# 2             131         2004        1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13405 entries, 0 to 13404
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   ISBN            13405 non-null  object
#  1   Name            13405 non-null  object
#  2   Authors         13405 non-null  object
#  3   Publisher       13405 non-null  object
#  4   Rating          13405 non-null  float64
#  5   pagesNumber     13405 non-null  int64
#  6   CountsOfReview  13405 non-null  int64
#  7   PublishYear     13405 non-null  int64
#  8   Cluster         13405 non-null  int64
# dtypes: float64(1), int64(4), object(4)
# memory usage: 1.0+ MB

# %% [markdown]
# ___
# ___

# %% [markdown]
# ## 2 Reconstrucción de variables categoricas.
# ___

# %% [markdown]
# ### 2.1 Pre-procesamiento.

# %%
cat_df = df[list(df.columns[df.dtypes == object])]
cat_df.sample(3)
# Out:
#             ISBN                                               Name  \
# 8984  0861404211  The First Discworld Novels: The Colour of Magi...
# 6874  0439545307  Charlie Bone and the Hidden King (The Children...
# 2525  1593076673  The Facts in the Case of the Departure of Miss...
#
#               Authors         Publisher
# 8984  Terry Pratchett      Colin Smythe
# 6874      Jenny Nimmo     Orchard Books
# 2525      Neil Gaiman  Dark Horse Books

# %%
# Concatenar los tres campos de nombre (N), autor (A) y editorial (P).

df['NAP'] = df.Name.str.cat(df.Authors, sep=" ").str.cat(df.Publisher, sep=" ")
df['NAP']
# Out:
# 0        Harry Potter and the Chamber of Secrets (Harry...
# 1        Unauthorized Harry Potter Book Seven News: "Ha...
# 2        Bryson's Dictionary of Troublesome Words: A Wr...
# 3        The Lord of the Rings: Weapons and Warfare Chr...
# 4        The Lord of the Rings: Complete Visual Compani...
#                                ...
# 13400    Thomas Paine and the Promise of America (Oxfor...
# 13401    Common Sense and Other Writings Thomas Paine B...
# 13402    Faith of My Fathers: A Family Memoir John McCa...
# 13403    Science Fiction: The Best of 2001 Robert Silve...
# 13404    Nebula Awards Showcase 2001 Robert Silverberg ...
# Name: NAP, Length: 13405, dtype: object

# %%
df['NAP'] = df['NAP'].str.lower()
df['NAP']
# Out:
# 0        harry potter and the chamber of secrets (harry...
# 1        unauthorized harry potter book seven news: "ha...
# 2        bryson's dictionary of troublesome words: a wr...
# 3        the lord of the rings: weapons and warfare chr...
# 4        the lord of the rings: complete visual compani...
#                                ...
# 13400    thomas paine and the promise of america (oxfor...
# 13401    common sense and other writings thomas paine b...
# 13402    faith of my fathers: a family memoir john mcca...
# 13403    science fiction: the best of 2001 robert silve...
# 13404    nebula awards showcase 2001 robert silverberg ...
# Name: NAP, Length: 13405, dtype: object

# %%
df['NAP'] = df['NAP'].apply(
    lambda linea: linea.translate(str.maketrans('', '', strg.punctuation))
    )
df['NAP']
# Out:
# 0        harry potter and the chamber of secrets harry ...
# 1        unauthorized harry potter book seven news half...
# 2        brysons dictionary of troublesome words a writ...
# 3        the lord of the rings weapons and warfare chri...
# 4        the lord of the rings complete visual companio...
#                                ...
# 13400    thomas paine and the promise of america oxford...
# 13401    common sense and other writings thomas paine b...
# 13402    faith of my fathers a family memoir john mccai...
# 13403    science fiction the best of 2001 robert silver...
# 13404    nebula awards showcase 2001 robert silverberg ...
# Name: NAP, Length: 13405, dtype: object

# %% [markdown]
# ___
# ___

# %% [markdown]
# ### 2.2 Vectorización

# %%
df['NAP'] = df['NAP'].apply(lambda registro: registro.split())
df['NAP']
# Out:
# 0        [harry, potter, and, the, chamber, of, secrets...
# 1        [unauthorized, harry, potter, book, seven, new...
# 2        [brysons, dictionary, of, troublesome, words, ...
# 3        [the, lord, of, the, rings, weapons, and, warf...
# 4        [the, lord, of, the, rings, complete, visual, ...
#                                ...
# 13400    [thomas, paine, and, the, promise, of, america...
# 13401    [common, sense, and, other, writings, thomas, ...
# 13402    [faith, of, my, fathers, a, family, memoir, jo...
# 13403    [science, fiction, the, best, of, 2001, robert...
# 13404    [nebula, awards, showcase, 2001, robert, silve...
# Name: NAP, Length: 13405, dtype: object

# %%
", ".join(stopwords.words('english'))
# Out:
# "i, me, my, myself, we, our, ours, ourselves, you, you're, you've, you'll, you'd, your, yours, yourself, yourselves, he, him, his, himself, she, she's, her, hers, herself, it, it's, its, itself, they, them, their, theirs, themselves, what, which, who, whom, this, that, that'll, these, those, am, is, are, was, were, be, been, being, have, has, had, having, do, does, did, doing, a, an, the, and, but, if, or, because, as, until, while, of, at, by, for, with, about, against, between, into, through, during, before, after, above, below, to, from, up, down, in, out, on, off, over, under, again, further, then, once, here, there, when, where, why, how, all, any, both, each, few, more, most, other, some, such, no, nor, not, only, own, same, so, than, too, very, s, t, can, will, just, don, don't, should, should've, now, d, ll, m, o, re, ve, y, ain, aren, aren't, couldn, couldn't, didn, didn't, doesn, doesn't, hadn, hadn't, hasn, hasn't, haven, haven't, isn, isn't, ma, mightn, mightn't, mustn, mustn't, needn, needn't, shan, shan't, shouldn, shouldn't, wasn, wasn't, weren, weren't, won, won't, wouldn, wouldn't"

# %%
df['NAP'] = df['NAP'].apply(
    lambda registro: [palabra for palabra in registro if palabra not in set(stopwords.words('english'))]
    )

df['NAP']
# Out:
# 0        [harry, potter, chamber, secrets, harry, potte...
# 1        [unauthorized, harry, potter, book, seven, new...
# 2        [brysons, dictionary, troublesome, words, writ...
# 3        [lord, rings, weapons, warfare, chris, smith, ...
# 4        [lord, rings, complete, visual, companion, jud...
#                                ...
# 13400    [thomas, paine, promise, america, oxford, port...
# 13401    [common, sense, writings, thomas, paine, barne...
# 13402    [faith, fathers, family, memoir, john, mccain,...
# 13403    [science, fiction, best, 2001, robert, silverb...
# 13404    [nebula, awards, showcase, 2001, robert, silve...
# Name: NAP, Length: 13405, dtype: object

# %%
# ["python","pythoner","pythoning","pythoned","pythonly"] ->  python

# %%
pal_der = PorterStemmer()

df['NAP'] = df['NAP'].apply(
    lambda registro: [pal_der.stem(palabra) for palabra in registro]
    )

df['NAP']
# Out:
# 0        [harri, potter, chamber, secret, harri, potter...
# 1        [unauthor, harri, potter, book, seven, news, h...
# 2        [bryson, dictionari, troublesom, word, writer,...
# 3        [lord, ring, weapon, warfar, chri, smith, houg...
# 4        [lord, ring, complet, visual, companion, jude,...
#                                ...
# 13400    [thoma, pain, promis, america, oxford, portrai...
# 13401    [common, sens, write, thoma, pain, barn, nobl,...
# 13402    [faith, father, famili, memoir, john, mccain, ...
# 13403    [scienc, fiction, best, 2001, robert, silverbe...
# 13404    [nebula, award, showcas, 2001, robert, silverb...
# Name: NAP, Length: 13405, dtype: object

# %%
pal_der = WordNetLemmatizer()

df['NAP'] = df['NAP'].apply(
    lambda registro: [pal_der.lemmatize(palabra) for palabra in registro]
    )

df['NAP']
# Out:
# 0        [harri, potter, chamber, secret, harri, potter...
# 1        [unauthor, harri, potter, book, seven, news, h...
# 2        [bryson, dictionari, troublesom, word, writer,...
# 3        [lord, ring, weapon, warfar, chri, smith, houg...
# 4        [lord, ring, complet, visual, companion, jude,...
#                                ...
# 13400    [thoma, pain, promis, america, oxford, portrai...
# 13401    [common, sen, write, thoma, pain, barn, nobl, ...
# 13402    [faith, father, famili, memoir, john, mccain, ...
# 13403    [scienc, fiction, best, 2001, robert, silverbe...
# 13404    [nebula, award, showcas, 2001, robert, silverb...
# Name: NAP, Length: 13405, dtype: object

# %%
df['NAP'] = df['NAP'].apply(
    lambda registro:" ".join(registro)
    )

df['NAP']
# Out:
# 0        harri potter chamber secret harri potter 2 jk ...
# 1        unauthor harri potter book seven news halfbloo...
# 2        bryson dictionari troublesom word writer guid ...
# 3        lord ring weapon warfar chri smith houghton mi...
# 4        lord ring complet visual companion jude fisher...
#                                ...
# 13400    thoma pain promis america oxford portrait harv...
# 13401        common sen write thoma pain barn nobl classic
# 13402    faith father famili memoir john mccain william...
# 13403    scienc fiction best 2001 robert silverberg fan...
# 13404    nebula award showcas 2001 robert silverberg ma...
# Name: NAP, Length: 13405, dtype: object

# %%
vec_df = CountVectorizer()

# %% [markdown]
# ___
# ___

# %% [markdown]
# ### 2.3 Semejanza

# %%
vec_df = vec_df.fit_transform(df['NAP'])
vec_df.shape
# Out:
# (13405, 16539)

# %%
sem_df = cosine_similarity(vec_df,vec_df)
sem_df.shape
# Out:
# (13405, 13405)

# %%
def orden_semejanza(ISBN):
    ind_sem = pd.Series(df.index, index=df['ISBN']).drop_duplicates()
    ind_sem = ind_sem[ISBN]

    sem = list(enumerate(sem_df[ind_sem]))
    sem = sorted(sem, key=lambda orden: orden[1], reverse=True)
   
    mask = [i[0] for i in sem]
    return df.iloc[mask].drop(columns = ['NAP'])

# %% [markdown]
# ___
# ___

# %% [markdown]
# ## 3 Recomendación

# %%
ISBN = '0439554896'

consulta = orden_semejanza(ISBN)
consulta.head(11)
# Out:
#             ISBN                                               Name  \
# 0     0439554896  Harry Potter and the Chamber of Secrets (Harry...
# 9674  1417751398  Harry Potter and the Half-blood Prince (Harry ...
# 7109  0439451930  Harry Potter and the Chamber of Secrets: A Mag...
# 311   0826452329  J.K. Rowling's Harry Potter Novels: A Reader's...
# 2288  1414306342                    Looking for God in Harry Potter
# 310   043932162X  Harry Potter Schoolbooks Box Set: Two Classic ...
# 2910  0723258058                           Beatrix Potter's Journal
# 4805  0812694554  Harry Potter and Philosophy: If Aristotle Ran ...
# 3173  0722189141                        The Secrets of Harry Bright
# 9945  032301741X  Virtual Clinical Excursions for Potter Fundame...
# 2384  0972393617  Ultimate Unofficial Guide to the Mysteries of ...
#
#                  Authors              Publisher  Rating  pagesNumber  \
# 0           J.K. Rowling             Scholastic    4.42          352
# 9674        J.K. Rowling       Turtleback Books    4.57          652
# 7109        Dena Neusner             Scholastic    4.36            5
# 311           Philip Nel    Bloomsbury Academic    3.59           96
# 2288        John Granger              SaltRiver    4.12          234
# 310         J.K. Rowling       Arthur A. Levine    4.40          240
# 2910      Beatrix Potter                  Warne    4.36           32
# 4805       David Baggett             Open Court    4.48          243
# 3173     Joseph Wambaugh                 Sphere    3.76          307
# 9945  Patricia A. Potter                  Mosby    3.90          495
# 2384    Galadriel Waters  Wizarding World Press    4.05          412
#
#       CountsOfReview  PublishYear  Cluster
# 0                244         2003        2
# 9674               9         2006        3
# 7109               3         2002        0
# 311                9         2001        0
# 2288              95         2006        1
# 310              140         2001        1
# 2910              42         2006        0
# 4805              78         2004        1
# 3173              26         1987        1
# 9945               0         2001        3
# 2384              38         2003        1

# %%
consulta[consulta['Cluster'] == 2].head(11).sort_index()
# Out:
#              ISBN                                               Name  \
# 0      0439554896  Harry Potter and the Chamber of Secrets (Harry...
# 618    0609602195                     The Barefoot Contessa Cookbook
# 2278   0060787112                                 Sleep, Pale Sister
# 2444   1585672319                     The Mating Season (Jeeves, #9)
# 2719   1585676160                                     Piccadilly Jim
# 3740   0810987902                           The Boy Who Couldn't Die
# 4920   0425196992              Shakespeare's Trollop (Lily Bard, #4)
# 6816   0743225082                     Man and Boy (Harry Silver, #1)
# 7493   1585670219                                Masters of Atlantis
# 8487   1585677647                                     Behold the Man
# 13347  0425201147            Shakespeare's Counselor (Lily Bard, #5)
#
#                 Authors                  Publisher  Rating  pagesNumber  \
# 0          J.K. Rowling                 Scholastic    4.42          352
# 618          Ina Garten            Clarkson Potter    4.16          256
# 2278      Joanne Harris  William Morrow Paperbacks    3.28          396
# 2444     P.G. Wodehouse            Harry N. Abrams    4.26          272
# 2719     P.G. Wodehouse            Harry N. Abrams    4.02          302
# 3740    William Sleator            Harry N. Abrams    3.68          161
# 4920   Charlaine Harris                    Berkley    3.87          194
# 6816       Tony Parsons                 Touchstone    3.57          368
# 7493     Charles Portis            Harry N. Abrams    3.74          248
# 8487   Michael Moorcock            Harry N. Abrams    3.78          144
# 13347  Charlaine Harris                    Berkley    3.90          243
#
#        CountsOfReview  PublishYear  Cluster
# 0                 244         2003        2
# 618               178         1999        2
# 2278              232         2005        2
# 2444              290         2002        2
# 2719              187         2004        2
# 3740              248         2005        2
# 4920              368         2004        2
# 6816              443         2002        2
# 7493              212         2000        2
# 8487              220         2007        2
# 13347             389         2005        2

# %% [markdown]
# > Ejemplo aleatorio

# %%
df.sample(5)
# Out:
#              ISBN                                               Name  \
# 4978   0684856271  Letter to a Man in the Fire: Does God Exist an...
# 3664   0764222376  Heathersleigh Homecoming (Secrets of Heathersl...
# 9601   0440128994                   God Save The Child (Spenser, #2)
# 12885  006112107X  Leaving Microsoft to Change the World: An Entr...
# 649    1932416595                          Housekeeping vs. the Dirt
#
#                    Authors                  Publisher  Rating  pagesNumber  \
# 4978        Reynolds Price                   Scribner    3.71          112
# 3664   Michael R. Phillips   Bethany House Publishers    4.34          429
# 9601      Robert B. Parker  Dell Publishing Co., Inc.    3.93          205
# 12885            John Wood            Harper Business    4.08          272
# 649            Nick Hornby                McSweeney's    3.88          153
#
#        CountsOfReview  PublishYear  Cluster  \
# 4978               22         2000        0
# 3664               16         1999        1
# 9601              332         1987        2
# 12885             416         2006        2
# 649               302         2006        2
#
#                                                      NAP
# 4978   letter man fire god exist care reynold price s...
# 3664   heathersleigh homecom secret heathersleigh hal...
# 9601   god save child spenser 2 robert b parker dell ...
# 12885  leav microsoft chang world entrepreneur odysse...
# 649               housekeep v dirt nick hornbi mcsweeney

# %%
ISBN = '0060887966'

consulta = orden_semejanza(ISBN)
consulta.head(11)
# Out:
#             ISBN                                               Name  \
# 155   0060887966                                      The Alchemist
# 217   0062513346                                      The Valkyries
# 218   0060930136                                 The Fifth Mountain
# 7670  0060528001                            The Devil and Miss Prym
# 9698  0062501755         The Diary of a Magus: The Road to Santiago
# 216   006251279X  The Pilgrimage: A Contemporary Quest for Ancie...
# 160   006019250X  The Illustrated Alchemist: A Fable about Follo...
# 7669  006133880X                            The Witch of Portobello
# 7671  0007114370             Paulo Coelho: Confessions of a Pilgrim
# 3973  1421502224  Fullmetal Alchemist: The Abducted Alchemist (F...
# 7648  0441014798     The Alchemist's Apprentice (The Alchemist, #1)
#
#            Authors                           Publisher  Rating  pagesNumber  \
# 155   Paulo Coelho                           HarperOne    3.87          192
# 217   Paulo Coelho                           HarperOne    3.31          212
# 218   Paulo Coelho                           HarperOne    3.62          256
# 7670  Paulo Coelho                           HarperOne    3.61          205
# 9698  Paulo Coelho                           HarperOne    3.65          226
# 216   Paulo Coelho                           HarperOne    3.65          272
# 160   Paulo Coelho            HarperCollins Publishers    3.87          198
# 7669  Paulo Coelho                       HarperCollins    3.54          268
# 7671    Juan Arias            HarperCollins Publishers    3.92          254
# 3973  Makoto Inoue                       VIZ Media LLC    4.57          240
# 7648   Dave Duncan  Ace (The Berkley Publishing Group)    3.57          313
#
#       CountsOfReview  PublishYear  Cluster
# 155               76         2006        0
# 217               87         1996        0
# 218               75         2000        1
# 7670              80         2007        0
# 9698               5         1992        0
# 216               95         1995        1
# 160               33         1998        0
# 7669             121         2007        1
# 7671              30         2001        1
# 3973              19         2006        1
# 7648              80         2007        1

# %% [markdown]
# $Z_{cal} = \frac{(\bar{x_A}-\bar{x_B})-(\bar{\mu_A}-\bar{\mu_B})}{\sqrt{\frac{s^2_A}{n_A} +\frac{s^2_B}{n_B}  }}$

# %%
consulta[consulta['Cluster'] == 0].head(11)
# Out:
#             ISBN                                               Name  \
# 155   0060887966                                      The Alchemist
# 217   0062513346                                      The Valkyries
# 7670  0060528001                            The Devil and Miss Prym
# 9698  0062501755         The Diary of a Magus: The Road to Santiago
# 160   006019250X  The Illustrated Alchemist: A Fable about Follo...
# 6631  0061351342  El Alquimista: Edicion Illustrada: Edicion Ill...
# 156   142150460X  Fullmetal Alchemist, Vol. 9 (Fullmetal Alchemi...
# 158   1421504596  Fullmetal Alchemist, Vol. 8 (Fullmetal Alchemi...
# 3693  0062511114                                A Manual for Living
# 4632  0060761539                            What Christians Believe
# 3492  1421508389  Fullmetal Alchemist, Vol. 11 (Fullmetal Alchem...
#
#              Authors                 Publisher  Rating  pagesNumber  \
# 155     Paulo Coelho                 HarperOne    3.87          192
# 217     Paulo Coelho                 HarperOne    3.31          212
# 7670    Paulo Coelho                 HarperOne    3.61          205
# 9698    Paulo Coelho                 HarperOne    3.65          226
# 160     Paulo Coelho  HarperCollins Publishers    3.87          198
# 6631    Paulo Coelho                      Rayo    3.87          192
# 156   Hiromu Arakawa             VIZ Media LLC    4.58          192
# 158   Hiromu Arakawa             VIZ Media LLC    4.57          192
# 3693       Epictetus                 HarperOne    4.23           96
# 4632      C.S. Lewis                 HarperOne    4.24           98
# 3492  Hiromu Arakawa             VIZ Media LLC    4.59          192
#
#       CountsOfReview  PublishYear  Cluster
# 155               76         2006        0
# 217               87         1996        0
# 7670              80         2007        0
# 9698               5         1992        0
# 160               33         1998        0
# 6631               5         2007        0
# 156              156         2006        0
# 158              159         2006        0
# 3693              15         1994        0
# 4632              72         2005        0
# 3492             130         2007        0

# %%
df.to_csv('1.5_encoding_dataset.csv')
